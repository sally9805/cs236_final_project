# %%
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader
# Out:
# Tesla T4, 15360 MiB, 15101 MiB

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/
# Out:
# /content/gdrive/My Drive

# %%
# ! git clone https://github.com/huggingface/diffusers.git

# %%
# %cd diffusers
# %pip install -e .
# Out:
# /content/gdrive/My Drive/diffusers
# Obtaining file:///content/gdrive/My%20Drive/diffusers
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0.dev0) (6.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0.dev0) (3.13.1)
# Collecting huggingface-hub>=0.13.2 (from diffusers==0.24.0.dev0)
#   Downloading huggingface_hub-0.19.0-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0.dev0) (1.23.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0.dev0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0.dev0) (2.31.0)
# Collecting safetensors>=0.3.1 (from diffusers==0.24.0.dev0)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0.dev0) (9.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.24.0.dev0) (2023.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.24.0.dev0) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.24.0.dev0) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.24.0.dev0) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.24.0.dev0) (23.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.24.0.dev0) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.24.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.24.0.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.24.0.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.24.0.dev0) (2023.7.22)
# Building wheels for collected packages: diffusers
#   Building editable for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.24.0.dev0-0.editable-py3-none-any.whl size=10640 sha256=c695c5204bc125280ee759531a7591ada6560957cd0ff91b3f91ef678788ea56
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2awhvwnb/wheels/a7/e8/6c/2fbea8a83feed974a924ccc4b63d7aa20ea56ab0f8127ee302
# Successfully built diffusers
# Installing collected packages: safetensors, huggingface-hub, diffusers
# Successfully installed diffusers-0.24.0.dev0 huggingface-hub-0.19.0 safetensors-0.4.0

# %%
# !ls
# Out:
# CITATION.cff	    docker  examples  MANIFEST.in     README.md    setup.cfg  tests
# CODE_OF_CONDUCT.md  docs    LICENSE   PHILOSOPHY.md   saved_model  setup.py   _typos.toml
# CONTRIBUTING.md     dog     Makefile  pyproject.toml  scripts	   src	      utils

# %%
# %pip install -U -r examples/dreambooth/requirements.txt
# Out:
# Collecting accelerate>=0.16.0 (from -r examples/dreambooth/requirements.txt (line 1))
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from -r examples/dreambooth/requirements.txt (line 2)) (0.16.0+cu118)
# Collecting transformers>=4.25.1 (from -r examples/dreambooth/requirements.txt (line 3))
#   Downloading transformers-4.35.0-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 36.7 MB/s eta 0:00:00
# Collecting ftfy (from -r examples/dreambooth/requirements.txt (line 4))
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from -r examples/dreambooth/requirements.txt (line 5)) (2.14.1)
# Collecting tensorboard (from -r examples/dreambooth/requirements.txt (line 5))
#   Downloading tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 86.4 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.10/dist-packages (from -r examples/dreambooth/requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.16.0->-r examples/dreambooth/requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.16.0->-r examples/dreambooth/requirements.txt (line 1)) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.16.0->-r examples/dreambooth/requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.16.0->-r examples/dreambooth/requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.16.0->-r examples/dreambooth/requirements.txt (line 1)) (2.1.0+cu118)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.16.0->-r examples/dreambooth/requirements.txt (line 1)) (0.19.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->-r examples/dreambooth/requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->-r examples/dreambooth/requirements.txt (line 2)) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.16.0->-r examples/dreambooth/requirements.txt (line 1)) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.16.0->-r examples/dreambooth/requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.16.0->-r examples/dreambooth/requirements.txt (line 1)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.16.0->-r examples/dreambooth/requirements.txt (line 1)) (3.2.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.16.0->-r examples/dreambooth/requirements.txt (line 1)) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=0.16.0->-r examples/dreambooth/requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->-r examples/dreambooth/requirements.txt (line 3)) (2023.6.3)
# Collecting tokenizers<0.15,>=0.14 (from transformers>=4.25.1->-r examples/dreambooth/requirements.txt (line 3))
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 104.9 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->-r examples/dreambooth/requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->-r examples/dreambooth/requirements.txt (line 3)) (4.66.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->-r examples/dreambooth/requirements.txt (line 4)) (0.2.9)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (1.59.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (3.5.1)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2->-r examples/dreambooth/requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->-r examples/dreambooth/requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->-r examples/dreambooth/requirements.txt (line 2)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->-r examples/dreambooth/requirements.txt (line 2)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->-r examples/dreambooth/requirements.txt (line 2)) (2023.7.22)
# Collecting huggingface-hub (from accelerate>=0.16.0->-r examples/dreambooth/requirements.txt (line 1))
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 36.2 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->-r examples/dreambooth/requirements.txt (line 5)) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate>=0.16.0->-r examples/dreambooth/requirements.txt (line 1)) (1.3.0)
# Installing collected packages: ftfy, huggingface-hub, tokenizers, accelerate, transformers, tensorboard
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.19.0
#     Uninstalling huggingface-hub-0.19.0:
#       Successfully uninstalled huggingface-hub-0.19.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.14.0 requires tensorboard<2.15,>=2.14, but you have tensorboard 2.15.1 which is incompatible.
# Successfully installed accelerate-0.24.1 ftfy-6.1.1 huggingface-hub-0.17.3 tensorboard-2.15.1 tokenizers-0.14.1 transformers-4.35.0

# %%
# !accelerate config default
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %%
from huggingface_hub import snapshot_download

local_dir = "./dog"
snapshot_download(
    "diffusers/dog-example",
    local_dir=local_dir,
    repo_type="dataset",
    ignore_patterns=".gitattributes",
)
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# '/content/gdrive/My Drive/diffusers/dog'

# %%
# %pip install huggingface_hub
# !python -c "from huggingface_hub.hf_api import HfFolder; HfFolder.save_token('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')"
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.17.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.7.22)

# %%
# %pip install bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.41.2.post2-py3-none-any.whl (92.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 20.3 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.41.2.post2

# %%
! accelerate launch examples/dreambooth/train_dreambooth.py \
  --pretrained_model_name_or_path="CompVis/stable-diffusion-v1-4"  \
  --instance_data_dir="./train_images" \
  --output_dir="saved_model" \
  --instance_prompt="a photo of sks dog" \
  --resolution=512 \
  --train_batch_size=1 \
  --train_text_encoder \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=5e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --max_train_steps=400 \
  --push_to_hub
# Out:
# 2023-11-13 05:32:21.874356: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-13 05:32:21.874407: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-13 05:32:21.874434: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-13 05:32:22.953173: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 11/13/2023 05:32:23 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: no
#
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'timestep_spacing', 'clip_sample_range', 'thresholding', 'sample_max_value', 'variance_type', 'dynamic_thresholding_ratio', 'prediction_type'} was not found in config. Values will be initialized to default values.
# {'norm_num_groups', 'force_upcast'} was not found in config. Values will be initialized to default values.
# {'num_class_embeds', 'reverse_transformer_layers_per_block', 'class_embeddings_concat', 'mid_block_only_cross_attention', 'only_cross_attention', 'resnet_skip_time_act', 'transformer_layers_per_block', 'encoder_hid_dim_type', 'upcast_attention', 'num_attention_heads', 'resnet_out_scale_factor', 'projection_class_embeddings_input_dim', 'time_embedding_type', 'cross_attention_norm', 'dropout', 'conv_in_kernel', 'mid_block_type', 'time_embedding_dim', 'conv_out_kernel', 'resnet_time_scale_shift', 'time_embedding_act_fn', 'encoder_hid_dim', 'addition_time_embed_dim', 'dual_cross_attention', 'time_cond_proj_dim', 'timestep_post_act', 'class_embed_type', 'attention_type', 'addition_embed_type', 'use_linear_projection', 'addition_embed_type_num_heads'} was not found in config. Values will be initialized to default values.
# 11/13/2023 05:32:31 - INFO - __main__ - ***** Running training *****
# 11/13/2023 05:32:31 - INFO - __main__ -   Num examples = 10
# 11/13/2023 05:32:31 - INFO - __main__ -   Num batches each epoch = 10
# 11/13/2023 05:32:31 - INFO - __main__ -   Num Epochs = 40
# 11/13/2023 05:32:31 - INFO - __main__ -   Instantaneous batch size per device = 1
# 11/13/2023 05:32:31 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 11/13/2023 05:32:31 - INFO - __main__ -   Gradient Accumulation steps = 1
# 11/13/2023 05:32:31 - INFO - __main__ -   Total optimization steps = 400
# Steps: 100% 400/400 [09:56<00:00,  1.49s/it, loss=0.305, lr=5e-6]
# Downloading (…)ain/model_index.json: 100% 541/541 [00:00<00:00, 3.18MB/s]
#
# Fetching 12 files:   0% 0/12 [00:00<?, ?it/s]
#
# Downloading (…)rocessor_config.json: 100% 342/342 [00:00<00:00, 2.29MB/s]
#
#
# Downloading model.safetensors:   0% 0.00/1.22G [00:00<?, ?B/s]
# Fetching 12 files:   8% 1/12 [00:00<00:07,  1.52it/s]
#
#
# Downloading (…)nfig-checkpoint.json: 100% 209/209 [00:00<00:00, 1.10MB/s]
#
#
# Downloading model.safetensors:   3% 41.9M/1.22G [00:00<00:03, 358MB/s]
#
# Downloading model.safetensors:   9% 105M/1.22G [00:00<00:02, 460MB/s]
#
# Downloading model.safetensors:  13% 157M/1.22G [00:00<00:02, 484MB/s]
#
#
# Downloading (…)_checker/config.json: 100% 4.56k/4.56k [00:00<00:00, 21.4MB/s]
#
# Fetching 12 files:  25% 3/12 [00:00<00:02,  3.37it/s]
#
# Downloading model.safetensors:  17% 210M/1.22G [00:00<00:02, 497MB/s]
#
# Downloading model.safetensors:  22% 262M/1.22G [00:00<00:01, 505MB/s]
#
# Downloading model.safetensors:  26% 315M/1.22G [00:00<00:01, 510MB/s]
#
# Downloading model.safetensors:  30% 367M/1.22G [00:00<00:01, 510MB/s]
#
# Downloading model.safetensors:  34% 419M/1.22G [00:00<00:01, 514MB/s]
#
# Downloading model.safetensors:  40% 482M/1.22G [00:00<00:01, 519MB/s]
#
# Downloading model.safetensors:  44% 535M/1.22G [00:01<00:01, 513MB/s]
#
# Downloading model.safetensors:  48% 587M/1.22G [00:01<00:01, 508MB/s]
#
# Downloading model.safetensors:  53% 640M/1.22G [00:01<00:01, 501MB/s]
#
# Downloading model.safetensors:  57% 692M/1.22G [00:01<00:01, 494MB/s]
#
# Downloading model.safetensors:  61% 744M/1.22G [00:01<00:00, 484MB/s]
#
# Downloading model.safetensors:  66% 797M/1.22G [00:01<00:00, 455MB/s]
#
# Downloading model.safetensors:  70% 849M/1.22G [00:01<00:00, 426MB/s]
#
# Downloading model.safetensors:  74% 902M/1.22G [00:01<00:00, 408MB/s]
#
# Downloading model.safetensors:  78% 954M/1.22G [00:02<00:00, 429MB/s]
#
# Downloading model.safetensors:  83% 1.01G/1.22G [00:02<00:00, 452MB/s]
#
# Downloading model.safetensors:  87% 1.06G/1.22G [00:02<00:00, 465MB/s]
#
# Downloading model.safetensors:  91% 1.11G/1.22G [00:02<00:00, 480MB/s]
#
# Downloading model.safetensors: 100% 1.22G/1.22G [00:02<00:00, 479MB/s]
#
# Fetching 12 files: 100% 12/12 [00:03<00:00,  3.75it/s]
# {'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]{'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'norm_num_groups', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86% 6/7 [00:00<00:00, 34.74it/s]`text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
# Loading pipeline components...: 100% 7/7 [00:00<00:00, 13.49it/s]
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Configuration saved in saved_model/vae/config.json
# Model weights saved in saved_model/vae/diffusion_pytorch_model.safetensors
# Configuration saved in saved_model/unet/config.json
# Model weights saved in saved_model/unet/diffusion_pytorch_model.safetensors
# Configuration saved in saved_model/scheduler/scheduler_config.json
# Configuration saved in saved_model/model_index.json
#
# Upload 10 LFS files:   0% 0/10 [00:00<?, ?it/s]
#
# events.out.tfevents.1699853139.ff83d4135c5d.3990.1:   0% 0.00/2.75k [00:00<?, ?B/s]
#
#
# events.out.tfevents.1699853551.ff83d4135c5d.5792.1:   0% 0.00/2.76k [00:00<?, ?B/s]
#
#
#
#
# events.out.tfevents.1699853139.ff83d4135c5d.3990.0:   0% 0.00/826 [00:00<?, ?B/s]
#
#
#
# events.out.tfevents.1699852260.63df1ff75774.4337.0:   0% 0.00/88.0 [00:00<?, ?B/s]
#
#
#
#
#
# events.out.tfevents.1699852260.63df1ff75774.4337.1:   0% 0.00/2.75k [00:00<?, ?B/s]
#
# events.out.tfevents.1699853139.ff83d4135c5d.3990.1: 100% 2.75k/2.75k [00:00<00:00, 2.79kB/s]
#
#
#
#
# events.out.tfevents.1699853139.ff83d4135c5d.3990.0: 100% 826/826 [00:00<00:00, 842B/s]
#
#
#
#
#
# events.out.tfevents.1699852260.63df1ff75774.4337.1: 100% 2.75k/2.75k [00:00<00:00, 2.79kB/s]
#
#
#
# events.out.tfevents.1699852260.63df1ff75774.4337.0: 100% 88.0/88.0 [00:00<00:00, 88.3B/s]
#
#
# events.out.tfevents.1699852260.63df1ff75774.4337.1: 100% 2.75k/2.75k [00:01<00:00, 2.37kB/s]
# events.out.tfevents.1699853551.ff83d4135c5d.5792.1: 100% 2.76k/2.76k [00:01<00:00, 2.35kB/s]
# events.out.tfevents.1699853139.ff83d4135c5d.3990.1: 100% 2.75k/2.75k [00:01<00:00, 2.32kB/s]
# events.out.tfevents.1699853139.ff83d4135c5d.3990.0: 100% 826/826 [00:01<00:00, 700B/s]
# events.out.tfevents.1699852260.63df1ff75774.4337.0: 100% 88.0/88.0 [00:01<00:00, 73.8B/s]
#
#
# events.out.tfevents.1699853551.ff83d4135c5d.5792.0:   0% 0.00/33.4k [00:00<?, ?B/s]
# Upload 10 LFS files:  10% 1/10 [00:01<00:12,  1.42s/it]
#
#
# model.safetensors:   0% 0.00/1.22G [00:00<?, ?B/s]
# Upload 10 LFS files:  20% 2/10 [00:01<00:05,  1.55it/s]
#
#
#
# model.safetensors:   0% 0.00/492M [00:00<?, ?B/s]
#
#
# model.safetensors:   0% 131k/1.22G [00:00<20:48, 974kB/s]
# Upload 10 LFS files:  50% 5/10 [00:01<00:01,  4.62it/s]
#
#
#
#
# events.out.tfevents.1699853551.ff83d4135c5d.5792.0: 100% 33.4k/33.4k [00:00<00:00, 99.9kB/s]
#
#
# diffusion_pytorch_model.safetensors:   0% 0.00/3.44G [00:00<?, ?B/s]
#
#
# model.safetensors:   0% 229k/1.22G [00:00<24:14, 836kB/s]
#
#
#
# model.safetensors:   0% 131k/492M [00:00<16:33, 495kB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   0% 98.3k/335M [00:00<07:33, 738kB/s]
#
#
# model.safetensors:   0% 328k/1.22G [00:00<25:09, 805kB/s]
#
# diffusion_pytorch_model.safetensors:   0% 131k/3.44G [00:00<58:46, 975kB/s]
#
#
#
# model.safetensors:   0% 377k/492M [00:00<07:41, 1.07MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   0% 180k/335M [00:00<08:16, 674kB/s]
#
#
# model.safetensors:   0% 770k/1.22G [00:00<11:09, 1.81MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 229k/3.44G [00:00<1:08:13, 840kB/s]
#
#
#
# model.safetensors:   0% 573k/492M [00:00<06:41, 1.22MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   0% 377k/335M [00:00<05:18, 1.05MB/s]
#
#
# model.safetensors:   0% 1.21M/1.22G [00:00<08:30, 2.38MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 328k/3.44G [00:00<1:11:57, 796kB/s]
#
#
#
# model.safetensors:   0% 1.46M/492M [00:00<02:37, 3.11MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   0% 590k/335M [00:00<04:23, 1.27MB/s]
#
#
# model.safetensors:   0% 2.69M/1.22G [00:00<03:45, 5.38MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 672k/3.44G [00:00<38:22, 1.49MB/s]
#
#
#
# model.safetensors:   0% 2.23M/492M [00:00<02:03, 3.98MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   0% 1.38M/335M [00:00<01:53, 2.93MB/s]
#
#
# model.safetensors:   0% 3.96M/1.22G [00:00<03:00, 6.72MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 1.43M/3.44G [00:00<19:26, 2.95MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   1% 2.15M/335M [00:00<01:26, 3.83MB/s]
#
#
# model.safetensors:   0% 5.55M/1.22G [00:01<02:27, 8.22MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 2.13M/3.44G [00:00<15:42, 3.65MB/s]
#
#
#
# model.safetensors:   1% 4.90M/492M [00:01<01:14, 6.57MB/s]
#
#
# model.safetensors:   1% 7.06M/1.22G [00:01<02:11, 9.20MB/s]
#
#
#
# model.safetensors:   1% 6.50M/492M [00:01<01:04, 7.54MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   1% 4.88M/335M [00:01<00:51, 6.35MB/s]
#
#
# model.safetensors:   1% 10.0M/1.22G [00:01<01:35, 12.6MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 4.62M/3.44G [00:01<09:45, 5.86MB/s]
#
#
#
# model.safetensors:   2% 9.75M/492M [00:01<00:44, 10.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   2% 6.55M/335M [00:01<00:44, 7.29MB/s]
#
#
# model.safetensors:   1% 13.5M/1.22G [00:01<01:17, 15.5MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 6.21M/3.44G [00:01<08:15, 6.93MB/s]
#
#
#
# model.safetensors:   2% 11.3M/492M [00:01<00:44, 10.8MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 7.75M/3.44G [00:01<07:30, 7.61MB/s]
#
#
#
# model.safetensors:   3% 14.4M/492M [00:01<00:36, 13.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   2% 8.08M/335M [00:01<00:52, 6.22MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 9.34M/3.44G [00:01<06:40, 8.57MB/s]
#
#
# model.safetensors:   1% 16.0M/1.22G [00:01<01:50, 10.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   3% 9.62M/335M [00:01<00:45, 7.09MB/s]
#
#
#
# model.safetensors:   3% 16.0M/492M [00:01<00:42, 11.1MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 10.9M/3.44G [00:01<06:13, 9.18MB/s]
#
#
# model.safetensors:   2% 20.0M/1.22G [00:02<01:23, 14.3MB/s]
#
#
#
# model.safetensors:   4% 20.0M/492M [00:02<00:32, 14.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   3% 11.1M/335M [00:01<00:43, 7.37MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 12.4M/3.44G [00:01<06:17, 9.08MB/s]
#
#
# model.safetensors:   2% 23.2M/1.22G [00:02<01:16, 15.5MB/s]
#
#
#
# model.safetensors:   4% 21.7M/492M [00:02<00:33, 14.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   4% 13.4M/335M [00:02<00:35, 8.97MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 13.9M/3.44G [00:02<06:17, 9.07MB/s]
#
#
# model.safetensors:   2% 26.3M/1.22G [00:02<01:12, 16.4MB/s]
#
#
#
# model.safetensors:   5% 24.7M/492M [00:02<00:30, 15.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   4% 14.9M/335M [00:02<00:35, 8.98MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 15.3M/3.44G [00:02<06:16, 9.08MB/s]
#
#
# model.safetensors:   2% 28.2M/1.22G [00:02<01:18, 15.1MB/s]
#
#
#
# model.safetensors:   5% 26.4M/492M [00:02<00:36, 12.7MB/s]
#
#
# model.safetensors:   3% 31.5M/1.22G [00:02<01:09, 17.0MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 16.3M/3.44G [00:02<08:35, 6.63MB/s]
#
#
#
# model.safetensors:   6% 29.5M/492M [00:02<00:31, 14.6MB/s]
#
#
# model.safetensors:   3% 33.3M/1.22G [00:02<01:26, 13.6MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 19.9M/3.44G [00:02<05:08, 11.1MB/s]
#
#
#
# model.safetensors:   6% 31.2M/492M [00:02<00:33, 13.6MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   5% 16.0M/335M [00:02<01:00, 5.29MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 21.9M/3.44G [00:02<04:51, 11.7MB/s]
#
#
# model.safetensors:   3% 36.0M/1.22G [00:03<01:20, 14.6MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   6% 19.9M/335M [00:02<00:36, 8.68MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 23.4M/3.44G [00:02<05:01, 11.3MB/s]
#
#
#
# model.safetensors:   7% 32.5M/492M [00:03<00:45, 10.1MB/s]
#
#
# model.safetensors:   3% 39.1M/1.22G [00:03<01:14, 15.8MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   6% 21.6M/335M [00:03<00:33, 9.24MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 26.4M/3.44G [00:03<04:17, 13.2MB/s]
#
#
#
# model.safetensors:   7% 35.9M/492M [00:03<00:35, 12.7MB/s]
#
#
# model.safetensors:   3% 42.3M/1.22G [00:03<01:11, 16.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   7% 23.3M/335M [00:03<00:33, 9.36MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 27.8M/3.44G [00:03<04:32, 12.5MB/s]
#
#
#
# model.safetensors:   8% 37.5M/492M [00:03<00:37, 12.0MB/s]
#
#
# model.safetensors:   4% 45.4M/1.22G [00:03<01:10, 16.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   7% 25.1M/335M [00:03<00:32, 9.62MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 30.6M/3.44G [00:03<04:09, 13.7MB/s]
#
#
#
# model.safetensors:   8% 40.4M/492M [00:03<00:34, 13.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   8% 26.7M/335M [00:03<00:31, 9.64MB/s]
#
#
# model.safetensors:   4% 48.0M/1.22G [00:03<01:32, 12.6MB/s]
#
#
#
# model.safetensors:   9% 43.3M/492M [00:03<00:33, 13.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   9% 30.0M/335M [00:03<00:24, 12.5MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 32.0M/3.44G [00:03<06:12, 9.15MB/s]
#
#
# model.safetensors:   4% 52.0M/1.22G [00:04<01:14, 15.5MB/s]
#
#
#
# model.safetensors:   9% 45.9M/492M [00:04<00:31, 14.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   9% 31.7M/335M [00:03<00:25, 11.7MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 36.0M/3.44G [00:03<04:26, 12.8MB/s]
#
#
#
# model.safetensors:  10% 47.3M/492M [00:04<00:32, 13.7MB/s]
#
#
# model.safetensors:   5% 55.0M/1.22G [00:04<01:12, 16.0MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 37.8M/3.44G [00:04<04:33, 12.4MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  10% 32.9M/335M [00:04<00:33, 9.08MB/s]
#
#
# model.safetensors:   5% 58.2M/1.22G [00:04<01:09, 16.6MB/s]
#
#
#
# model.safetensors:  10% 48.7M/492M [00:04<00:44, 10.1MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 41.2M/3.44G [00:04<03:47, 15.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  11% 36.0M/335M [00:04<00:25, 11.6MB/s]
#
#
# model.safetensors:   5% 61.4M/1.22G [00:04<01:07, 17.2MB/s]
#
#
#
# model.safetensors:  11% 52.0M/492M [00:04<00:35, 12.4MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 44.4M/3.44G [00:04<03:37, 15.6MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  11% 37.8M/335M [00:04<00:26, 11.2MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 47.5M/3.44G [00:04<03:32, 16.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  12% 41.3M/335M [00:04<00:21, 13.4MB/s]
#
#
#
# model.safetensors:  11% 53.8M/492M [00:05<00:46, 9.47MB/s]
#
#
# model.safetensors:   5% 64.0M/1.22G [00:05<01:40, 11.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  13% 43.0M/335M [00:04<00:21, 13.6MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 49.1M/3.44G [00:04<04:22, 12.9MB/s]
#
#
#
# model.safetensors:  12% 57.0M/492M [00:05<00:36, 11.9MB/s]
#
#
# model.safetensors:   6% 68.0M/1.22G [00:05<01:20, 14.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  14% 46.1M/335M [00:05<00:19, 14.9MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 52.0M/3.44G [00:05<04:10, 13.5MB/s]
#
#
#
# model.safetensors:  12% 58.7M/492M [00:05<00:38, 11.1MB/s]
#
#
# model.safetensors:   6% 71.2M/1.22G [00:05<01:15, 15.2MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 55.0M/3.44G [00:05<03:53, 14.5MB/s]
#
#
#
# model.safetensors:  12% 60.2M/492M [00:05<00:40, 10.6MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  14% 48.0M/335M [00:05<00:25, 11.1MB/s]
#
#
# model.safetensors:   6% 74.4M/1.22G [00:05<01:11, 15.9MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 58.2M/3.44G [00:05<03:30, 16.1MB/s]
#
#
#
# model.safetensors:  13% 61.9M/492M [00:05<00:40, 10.6MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  16% 52.0M/335M [00:05<00:19, 14.1MB/s]
#
#
# model.safetensors:   6% 77.5M/1.22G [00:05<01:10, 16.2MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 61.5M/3.44G [00:05<03:23, 16.6MB/s]
#
#
#
# model.safetensors:  13% 63.3M/492M [00:05<00:41, 10.4MB/s]
#
#
# model.safetensors:   7% 79.3M/1.22G [00:05<01:12, 15.6MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  16% 55.1M/335M [00:05<00:18, 15.1MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 63.2M/3.44G [00:05<03:47, 14.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  17% 57.1M/335M [00:05<00:19, 14.3MB/s]
#
#
#
# model.safetensors:  13% 64.4M/492M [00:06<00:56, 7.56MB/s]
#
#
# model.safetensors:   7% 80.9M/1.22G [00:06<01:38, 11.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  18% 60.4M/335M [00:06<00:16, 16.7MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 64.7M/3.44G [00:05<05:02, 11.1MB/s]
#
#
#
# model.safetensors:  14% 67.9M/492M [00:06<00:38, 11.1MB/s]
#
#
# model.safetensors:   7% 84.0M/1.22G [00:06<01:24, 13.4MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  19% 63.5M/335M [00:06<00:15, 17.2MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 68.0M/3.44G [00:06<04:15, 13.2MB/s]
#
#
#
# model.safetensors:  14% 69.9M/492M [00:06<00:38, 10.9MB/s]
#
#
# model.safetensors:   7% 87.2M/1.22G [00:06<01:17, 14.5MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 70.0M/3.44G [00:06<04:16, 13.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  20% 65.3M/335M [00:06<00:19, 13.5MB/s]
#
#
#
# model.safetensors:  15% 71.4M/492M [00:06<00:39, 10.6MB/s]
#
#
# model.safetensors:   7% 89.0M/1.22G [00:06<01:21, 13.9MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 74.0M/3.44G [00:06<03:29, 16.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  20% 68.0M/335M [00:06<00:18, 14.2MB/s]
#
#
#
# model.safetensors:  15% 73.2M/492M [00:06<00:40, 10.2MB/s]
#
#
# model.safetensors:   8% 92.2M/1.22G [00:06<01:16, 14.7MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 76.1M/3.44G [00:06<03:36, 15.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  21% 71.1M/335M [00:06<00:17, 15.2MB/s]
#
#
#
# model.safetensors:  15% 74.7M/492M [00:06<00:41, 10.1MB/s]
#
#
# model.safetensors:   8% 95.5M/1.22G [00:07<01:11, 15.7MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 79.2M/3.44G [00:06<03:27, 16.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  22% 74.2M/335M [00:06<00:16, 15.7MB/s]
#
#
#
# model.safetensors:  16% 77.7M/492M [00:07<00:36, 11.4MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  23% 77.4M/335M [00:07<00:15, 17.0MB/s]
#
#
# model.safetensors:   8% 97.1M/1.22G [00:07<01:33, 12.0MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 80.9M/3.44G [00:07<04:29, 12.5MB/s]
#
#
#
# model.safetensors:  16% 79.4M/492M [00:07<00:36, 11.2MB/s]
#
#
# model.safetensors:   8% 100M/1.22G [00:07<01:23, 13.4MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 84.0M/3.44G [00:07<04:06, 13.6MB/s]
#
#
# model.safetensors:   8% 103M/1.22G [00:07<01:12, 15.4MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 87.1M/3.44G [00:07<03:43, 15.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  24% 80.0M/335M [00:07<00:21, 11.8MB/s]
#
#
#
# model.safetensors:  16% 80.5M/492M [00:07<00:57, 7.16MB/s]
#
#
# model.safetensors:   9% 106M/1.22G [00:07<01:05, 17.0MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 89.2M/3.44G [00:07<03:42, 15.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  25% 84.0M/335M [00:07<00:17, 14.4MB/s]
#
#
#
# model.safetensors:  17% 83.9M/492M [00:07<00:41, 9.87MB/s]
#
#
# model.safetensors:   9% 109M/1.22G [00:07<01:05, 16.8MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 92.2M/3.44G [00:07<03:32, 15.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  26% 87.1M/335M [00:07<00:16, 15.2MB/s]
#
#
#
# model.safetensors:  17% 85.5M/492M [00:08<00:42, 9.63MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 95.3M/3.44G [00:07<03:25, 16.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  27% 88.9M/335M [00:08<00:16, 14.5MB/s]
#
#
#
# model.safetensors:  18% 87.2M/492M [00:08<00:42, 9.63MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  27% 92.0M/335M [00:08<00:15, 16.0MB/s]
#
#
# model.safetensors:   9% 112M/1.22G [00:08<01:37, 11.3MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 97.0M/3.44G [00:08<04:12, 13.3MB/s]
#
#
#
# model.safetensors:  18% 90.3M/492M [00:08<00:33, 12.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  29% 95.5M/335M [00:08<00:13, 18.0MB/s]
#
#
# model.safetensors:  10% 116M/1.22G [00:08<01:18, 14.0MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 100M/3.44G [00:08<03:55, 14.1MB/s]
#
#
#
# model.safetensors:  19% 91.8M/492M [00:08<00:36, 10.9MB/s]
#
#
# model.safetensors:  10% 119M/1.22G [00:08<01:12, 15.1MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 103M/3.44G [00:08<03:37, 15.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  29% 97.4M/335M [00:08<00:17, 13.6MB/s]
#
#
#
# model.safetensors:  19% 93.3M/492M [00:08<00:38, 10.3MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 105M/3.44G [00:08<03:29, 15.9MB/s]
#
#
# model.safetensors:  10% 122M/1.22G [00:08<01:07, 16.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  30% 100M/335M [00:08<00:16, 13.9MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 108M/3.44G [00:08<03:25, 16.2MB/s]
#
#
# model.safetensors:  10% 125M/1.22G [00:09<01:05, 16.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  31% 103M/335M [00:08<00:15, 14.9MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 111M/3.44G [00:08<03:18, 16.7MB/s]
#
#
#
# model.safetensors:  20% 96.0M/492M [00:09<00:51, 7.74MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  32% 106M/335M [00:09<00:14, 15.7MB/s]
#
#
# model.safetensors:  11% 128M/1.22G [00:09<01:22, 13.1MB/s]
#
#
#
# model.safetensors:  20% 99.9M/492M [00:09<00:35, 11.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  33% 109M/335M [00:09<00:13, 16.8MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 113M/3.44G [00:09<04:21, 12.7MB/s]
#
#
# model.safetensors:  11% 132M/1.22G [00:09<01:07, 16.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  33% 111M/335M [00:09<00:13, 16.6MB/s]
#
#
#
# model.safetensors:  21% 101M/492M [00:09<00:36, 10.7MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 116M/3.44G [00:09<03:59, 13.9MB/s]
#
#
# model.safetensors:  11% 135M/1.22G [00:09<01:05, 16.4MB/s]
#
#
#
# model.safetensors:  21% 103M/492M [00:09<00:35, 11.0MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 119M/3.44G [00:09<03:39, 15.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  34% 113M/335M [00:09<00:18, 12.1MB/s]
#
#
# model.safetensors:  11% 138M/1.22G [00:09<01:03, 16.9MB/s]
#
#
#
# model.safetensors:  22% 106M/492M [00:09<00:30, 12.7MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 122M/3.44G [00:09<03:23, 16.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  35% 116M/335M [00:09<00:16, 13.5MB/s]
#
#
# model.safetensors:  12% 142M/1.22G [00:10<01:03, 16.9MB/s]
#
#
#
# model.safetensors:  22% 108M/492M [00:10<00:32, 11.8MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 125M/3.44G [00:09<03:19, 16.6MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  36% 119M/335M [00:10<00:14, 14.6MB/s]
#
#
#
# model.safetensors:  22% 110M/492M [00:10<00:33, 11.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  37% 122M/335M [00:10<00:13, 15.3MB/s]
#
#
# model.safetensors:  12% 144M/1.22G [00:10<01:30, 11.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  37% 125M/335M [00:10<00:12, 16.8MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 128M/3.44G [00:10<04:39, 11.8MB/s]
#
#
# model.safetensors:  12% 148M/1.22G [00:10<01:11, 14.9MB/s]
#
#
#
# model.safetensors:  23% 112M/492M [00:10<00:43, 8.74MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  38% 127M/335M [00:10<00:13, 15.9MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 132M/3.44G [00:10<03:47, 14.6MB/s]
#
#
# model.safetensors:  12% 151M/1.22G [00:10<01:07, 15.8MB/s]
#
#
#
# model.safetensors:  24% 116M/492M [00:10<00:31, 12.0MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 134M/3.44G [00:10<03:56, 14.0MB/s]
#
#
# model.safetensors:  13% 154M/1.22G [00:10<01:02, 17.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  38% 129M/335M [00:10<00:18, 11.3MB/s]
#
#
#
# model.safetensors:  24% 118M/492M [00:10<00:31, 12.1MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 137M/3.44G [00:10<03:17, 16.7MB/s]
#
#
# model.safetensors:  13% 157M/1.22G [00:11<00:56, 18.7MB/s]
#
#
#
# model.safetensors:  24% 119M/492M [00:11<00:30, 12.4MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  39% 132M/335M [00:10<00:14, 14.0MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 141M/3.44G [00:10<02:59, 18.3MB/s]
#
#
# model.safetensors:  13% 160M/1.22G [00:11<00:57, 18.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  40% 135M/335M [00:11<00:12, 15.9MB/s]
#
#
#
# model.safetensors:  25% 122M/492M [00:11<00:27, 13.3MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 143M/3.44G [00:11<03:08, 17.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  41% 138M/335M [00:11<00:10, 17.9MB/s]
#
#
# model.safetensors:  13% 162M/1.22G [00:11<01:11, 14.8MB/s]
#
#
#
# model.safetensors:  25% 125M/492M [00:11<00:24, 15.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  42% 141M/335M [00:11<00:09, 19.9MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 145M/3.44G [00:11<03:54, 14.1MB/s]
#
#
# model.safetensors:  13% 164M/1.22G [00:11<01:06, 15.8MB/s]
#
#
#
# model.safetensors:  26% 127M/492M [00:11<00:25, 14.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  43% 144M/335M [00:11<00:09, 20.2MB/s]
# Upload 10 LFS files:  50% 5/10 [00:13<00:01,  4.62it/s]
#
# diffusion_pytorch_model.safetensors:   4% 148M/3.44G [00:11<03:23, 16.1MB/s]
#
#
# model.safetensors:  14% 167M/1.22G [00:11<01:01, 17.0MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 151M/3.44G [00:11<03:01, 18.1MB/s]
#
#
# model.safetensors:  14% 170M/1.22G [00:11<00:56, 18.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  44% 146M/335M [00:11<00:12, 15.4MB/s]
#
#
#
# model.safetensors:  26% 128M/492M [00:11<00:36, 10.0MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 154M/3.44G [00:11<02:44, 19.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  44% 148M/335M [00:11<00:11, 15.8MB/s]
#
#
# model.safetensors:  14% 173M/1.22G [00:12<00:53, 19.5MB/s]
#
#
#
# model.safetensors:  27% 132M/492M [00:12<00:26, 13.6MB/s]
#
# diffusion_pytorch_model.safetensors:   5% 157M/3.44G [00:11<02:41, 20.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  45% 151M/335M [00:11<00:10, 17.6MB/s]
#
#
#
# model.safetensors:  27% 134M/492M [00:12<00:27, 13.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  46% 154M/335M [00:12<00:09, 18.6MB/s]
#
#
#
# model.safetensors:  27% 135M/492M [00:12<00:27, 13.0MB/s]
#
#
# model.safetensors:  14% 176M/1.22G [00:12<01:14, 13.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  47% 157M/335M [00:12<00:08, 20.7MB/s]
#
# diffusion_pytorch_model.safetensors:   5% 160M/3.44G [00:12<03:45, 14.5MB/s]
#
#
#
# model.safetensors:  28% 138M/492M [00:12<00:22, 15.7MB/s]
#
#
# model.safetensors:  15% 180M/1.22G [00:12<00:59, 17.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  48% 160M/335M [00:12<00:08, 20.4MB/s]
#
# diffusion_pytorch_model.safetensors:   5% 164M/3.44G [00:12<03:06, 17.6MB/s]
#
#
#
# model.safetensors:  28% 140M/492M [00:12<00:23, 14.8MB/s]
#
#
# model.safetensors:  15% 183M/1.22G [00:12<00:56, 18.3MB/s]
#
# diffusion_pytorch_model.safetensors:   5% 167M/3.44G [00:12<02:52, 18.9MB/s]
#
#
#
# model.safetensors:  29% 143M/492M [00:12<00:21, 16.1MB/s]
#
#
# model.safetensors:  15% 186M/1.22G [00:12<00:53, 19.4MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  48% 162M/335M [00:12<00:11, 14.7MB/s]
#
# diffusion_pytorch_model.safetensors:   5% 170M/3.44G [00:12<02:42, 20.1MB/s]
#
#
# model.safetensors:  16% 190M/1.22G [00:12<00:50, 20.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  49% 164M/335M [00:12<00:11, 15.1MB/s]
#
# diffusion_pytorch_model.safetensors:   5% 173M/3.44G [00:12<02:42, 20.1MB/s]
#
#
# model.safetensors:  16% 192M/1.22G [00:13<00:50, 20.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  50% 167M/335M [00:12<00:09, 17.2MB/s]
#
#
#
# model.safetensors:  29% 145M/492M [00:13<00:31, 10.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  50% 169M/335M [00:12<00:09, 17.3MB/s]
#
#
# model.safetensors:  16% 194M/1.22G [00:13<00:58, 17.5MB/s]
#
#
#
# model.safetensors:  30% 148M/492M [00:13<00:24, 13.8MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  52% 172M/335M [00:13<00:07, 20.3MB/s]
#
#
# model.safetensors:  16% 196M/1.22G [00:13<00:58, 17.4MB/s]
#
# diffusion_pytorch_model.safetensors:   5% 176M/3.44G [00:13<03:48, 14.3MB/s]
#
#
#
# model.safetensors:  30% 150M/492M [00:13<00:25, 13.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  52% 176M/335M [00:13<00:07, 21.7MB/s]
#
#
# model.safetensors:  16% 198M/1.22G [00:13<00:56, 17.9MB/s]
#
# diffusion_pytorch_model.safetensors:   5% 180M/3.44G [00:13<03:08, 17.2MB/s]
#
#
#
# model.safetensors:  31% 151M/492M [00:13<00:27, 12.3MB/s]
#
#
# model.safetensors:  17% 201M/1.22G [00:13<00:53, 19.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  53% 178M/335M [00:13<00:09, 16.7MB/s]
#
#
#
# model.safetensors:  31% 154M/492M [00:13<00:22, 14.8MB/s]
#
#
# model.safetensors:  17% 204M/1.22G [00:13<00:49, 20.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  54% 180M/335M [00:13<00:09, 16.9MB/s]
#
#
#
# model.safetensors:  32% 156M/492M [00:13<00:23, 14.2MB/s]
#
#
# model.safetensors:  17% 208M/1.22G [00:13<00:47, 21.4MB/s]
#
# diffusion_pytorch_model.safetensors:   5% 183M/3.44G [00:13<04:09, 13.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  54% 182M/335M [00:13<00:09, 17.0MB/s]
#
#
#
# model.safetensors:  32% 159M/492M [00:13<00:20, 16.5MB/s]
#
#
# model.safetensors:  17% 210M/1.22G [00:13<00:55, 18.3MB/s]
#
# diffusion_pytorch_model.safetensors:   5% 187M/3.44G [00:13<03:29, 15.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  55% 185M/335M [00:13<00:08, 18.6MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 189M/3.44G [00:13<03:18, 16.4MB/s]
#
#
# model.safetensors:  17% 212M/1.22G [00:14<00:55, 18.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  56% 188M/335M [00:13<00:07, 19.5MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 191M/3.44G [00:13<03:14, 16.7MB/s]
#
#
# model.safetensors:  18% 215M/1.22G [00:14<00:50, 19.8MB/s]
#
#
#
# model.safetensors:  33% 161M/492M [00:14<00:29, 11.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  57% 191M/335M [00:14<00:07, 20.1MB/s]
#
#
# model.safetensors:  18% 218M/1.22G [00:14<00:47, 21.0MB/s]
#
#
#
# model.safetensors:  33% 164M/492M [00:14<00:24, 13.2MB/s]
#
#
# model.safetensors:  18% 222M/1.22G [00:14<00:44, 22.5MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 193M/3.44G [00:14<04:27, 12.1MB/s]
#
#
#
# model.safetensors:  34% 166M/492M [00:14<00:23, 13.6MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  58% 194M/335M [00:14<00:09, 15.3MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 196M/3.44G [00:14<03:47, 14.3MB/s]
#
#
#
# model.safetensors:  34% 168M/492M [00:14<00:23, 13.8MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  59% 196M/335M [00:14<00:08, 15.5MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 198M/3.44G [00:14<03:45, 14.4MB/s]
#
#
# model.safetensors:  18% 224M/1.22G [00:14<01:04, 15.4MB/s]
#
#
#
# model.safetensors:  35% 171M/492M [00:14<00:20, 15.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  60% 199M/335M [00:14<00:07, 17.5MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 201M/3.44G [00:14<03:15, 16.6MB/s]
#
#
#
# model.safetensors:  35% 172M/492M [00:14<00:20, 15.5MB/s]
#
#
# model.safetensors:  19% 228M/1.22G [00:14<00:53, 18.6MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  60% 202M/335M [00:14<00:07, 18.2MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 203M/3.44G [00:14<03:24, 15.8MB/s]
#
#
# model.safetensors:  19% 231M/1.22G [00:15<00:50, 19.6MB/s]
#
#
#
# model.safetensors:  36% 175M/492M [00:15<00:20, 15.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  61% 205M/335M [00:14<00:06, 19.2MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 206M/3.44G [00:14<03:10, 16.9MB/s]
#
#
# model.safetensors:  19% 234M/1.22G [00:15<00:49, 19.9MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 208M/3.44G [00:15<03:19, 16.2MB/s]
#
#
# model.safetensors:  20% 237M/1.22G [00:15<00:47, 20.8MB/s]
#
#
#
# model.safetensors:  36% 177M/492M [00:15<00:29, 10.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  62% 208M/335M [00:15<00:09, 13.7MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 209M/3.44G [00:15<03:46, 14.3MB/s]
#
#
#
# model.safetensors:  37% 180M/492M [00:15<00:23, 13.4MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  63% 212M/335M [00:15<00:07, 17.0MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 212M/3.44G [00:15<03:32, 15.2MB/s]
#
#
#
# model.safetensors:  37% 182M/492M [00:15<00:22, 14.0MB/s]
#
#
# model.safetensors:  20% 240M/1.22G [00:15<01:07, 14.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  64% 215M/335M [00:15<00:06, 18.9MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 214M/3.44G [00:15<03:44, 14.4MB/s]
#
#
#
# model.safetensors:  37% 183M/492M [00:15<00:22, 13.7MB/s]
#
#
# model.safetensors:  20% 244M/1.22G [00:15<00:55, 17.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  65% 218M/335M [00:15<00:05, 19.4MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 217M/3.44G [00:15<03:11, 16.8MB/s]
#
#
#
# model.safetensors:  38% 187M/492M [00:15<00:19, 15.7MB/s]
#
#
# model.safetensors:  20% 247M/1.22G [00:15<00:51, 18.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  66% 221M/335M [00:15<00:05, 19.7MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 219M/3.44G [00:15<03:28, 15.5MB/s]
#
#
#
# model.safetensors:  38% 188M/492M [00:16<00:20, 14.7MB/s]
#
#
# model.safetensors:  21% 250M/1.22G [00:16<00:48, 19.7MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 222M/3.44G [00:15<03:08, 17.1MB/s]
#
#
#
# model.safetensors:  39% 191M/492M [00:16<00:18, 16.1MB/s]
#
#
# model.safetensors:  21% 253M/1.22G [00:16<00:47, 20.1MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 224M/3.44G [00:16<03:06, 17.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  67% 224M/335M [00:16<00:07, 13.9MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 226M/3.44G [00:16<03:34, 15.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  68% 228M/335M [00:16<00:06, 17.6MB/s]
#
#
#
# model.safetensors:  39% 193M/492M [00:16<00:27, 11.0MB/s]
#
#
# model.safetensors:  21% 256M/1.22G [00:16<01:04, 14.9MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 228M/3.44G [00:16<03:17, 16.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  69% 231M/335M [00:16<00:05, 18.9MB/s]
#
#
#
# model.safetensors:  40% 196M/492M [00:16<00:21, 13.9MB/s]
#
#
# model.safetensors:  21% 260M/1.22G [00:16<00:53, 18.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  70% 233M/335M [00:16<00:05, 19.1MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 230M/3.44G [00:16<03:36, 14.8MB/s]
#
#
#
# model.safetensors:  40% 198M/492M [00:16<00:21, 13.5MB/s]
#
#
# model.safetensors:  22% 263M/1.22G [00:16<00:49, 19.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  70% 236M/335M [00:16<00:05, 18.5MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 233M/3.44G [00:16<03:13, 16.6MB/s]
#
#
#
# model.safetensors:  40% 199M/492M [00:16<00:22, 13.0MB/s]
#
#
# model.safetensors:  22% 266M/1.22G [00:17<00:48, 19.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  71% 239M/335M [00:16<00:04, 19.3MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 236M/3.44G [00:16<03:01, 17.7MB/s]
#
#
#
# model.safetensors:  41% 202M/492M [00:17<00:19, 15.1MB/s]
#
#
# model.safetensors:  22% 269M/1.22G [00:17<00:47, 20.1MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 238M/3.44G [00:16<03:04, 17.3MB/s]
#
#
#
# model.safetensors:  41% 204M/492M [00:17<00:19, 14.8MB/s]
#
#
# model.safetensors:  22% 272M/1.22G [00:17<00:47, 20.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  72% 241M/335M [00:17<00:06, 14.5MB/s]
#
#
#
# model.safetensors:  42% 207M/492M [00:17<00:16, 17.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  73% 244M/335M [00:17<00:05, 16.3MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 240M/3.44G [00:17<03:58, 13.4MB/s]
#
#
# model.safetensors:  23% 274M/1.22G [00:17<00:55, 16.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  74% 246M/335M [00:17<00:05, 17.6MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 244M/3.44G [00:17<03:09, 16.9MB/s]
#
#
# model.safetensors:  23% 276M/1.22G [00:17<00:58, 16.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  75% 249M/335M [00:17<00:04, 19.5MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 246M/3.44G [00:17<03:08, 16.9MB/s]
#
#
#
# model.safetensors:  42% 209M/492M [00:17<00:26, 10.9MB/s]
#
#
# model.safetensors:  23% 279M/1.22G [00:17<00:52, 17.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  76% 253M/335M [00:17<00:03, 20.8MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 249M/3.44G [00:17<02:55, 18.1MB/s]
#
#
#
# model.safetensors:  43% 212M/492M [00:17<00:22, 12.6MB/s]
#
#
# model.safetensors:  23% 282M/1.22G [00:17<00:50, 18.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  76% 256M/335M [00:17<00:03, 20.7MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 251M/3.44G [00:17<02:57, 18.0MB/s]
#
#
#
# model.safetensors:  43% 214M/492M [00:18<00:22, 12.6MB/s]
#
#
# model.safetensors:  23% 286M/1.22G [00:18<00:48, 19.1MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 255M/3.44G [00:17<02:34, 20.5MB/s]
#
#
#
# model.safetensors:  44% 216M/492M [00:18<00:19, 14.4MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  77% 258M/335M [00:18<00:04, 16.2MB/s]
#
#
# model.safetensors:  24% 288M/1.22G [00:18<00:57, 16.2MB/s]
#
#
#
# model.safetensors:  44% 218M/492M [00:18<00:19, 14.3MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 257M/3.44G [00:18<03:08, 16.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  78% 260M/335M [00:18<00:04, 15.6MB/s]
#
#
# model.safetensors:  24% 292M/1.22G [00:18<00:47, 19.6MB/s]
#
#
#
# model.safetensors:  45% 220M/492M [00:18<00:19, 14.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  78% 262M/335M [00:18<00:04, 15.3MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 260M/3.44G [00:18<03:06, 17.0MB/s]
#
#
# model.safetensors:  24% 294M/1.22G [00:18<00:47, 19.3MB/s]
#
#
#
# model.safetensors:  45% 222M/492M [00:18<00:17, 15.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  79% 265M/335M [00:18<00:03, 17.4MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 262M/3.44G [00:18<03:15, 16.3MB/s]
#
#
#
# model.safetensors:  45% 224M/492M [00:18<00:18, 14.7MB/s]
#
#
# model.safetensors:  24% 297M/1.22G [00:18<00:45, 20.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  80% 268M/335M [00:18<00:03, 18.5MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 265M/3.44G [00:18<02:59, 17.7MB/s]
#
#
# model.safetensors:  25% 301M/1.22G [00:18<00:42, 21.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  81% 271M/335M [00:18<00:03, 19.9MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 268M/3.44G [00:18<02:41, 19.6MB/s]
#
#
#
# model.safetensors:  46% 225M/492M [00:18<00:23, 11.2MB/s]
#
#
# model.safetensors:  25% 304M/1.22G [00:18<00:43, 20.9MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 271M/3.44G [00:18<02:34, 20.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  82% 274M/335M [00:18<00:03, 17.6MB/s]
#
#
#
# model.safetensors:  46% 228M/492M [00:19<00:19, 13.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  82% 276M/335M [00:18<00:03, 18.0MB/s]
#
#
# model.safetensors:  25% 306M/1.22G [00:19<00:56, 16.0MB/s]
#
#
#
# model.safetensors:  47% 230M/492M [00:19<00:20, 12.8MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 273M/3.44G [00:18<03:08, 16.8MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  83% 279M/335M [00:19<00:02, 20.3MB/s]
#
#
#
# model.safetensors:  47% 231M/492M [00:19<00:19, 13.3MB/s]
#
#
# model.safetensors:  25% 308M/1.22G [00:19<00:56, 16.2MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 276M/3.44G [00:19<03:14, 16.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  84% 282M/335M [00:19<00:02, 20.6MB/s]
#
#
# model.safetensors:  26% 311M/1.22G [00:19<00:50, 17.8MB/s]
#
#
#
# model.safetensors:  48% 234M/492M [00:19<00:18, 13.9MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 278M/3.44G [00:19<03:25, 15.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  85% 285M/335M [00:19<00:02, 20.8MB/s]
#
#
# model.safetensors:  26% 314M/1.22G [00:19<00:48, 18.7MB/s]
#
#
#
# model.safetensors:  48% 237M/492M [00:19<00:16, 15.4MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 281M/3.44G [00:19<03:04, 17.1MB/s]
#
#
# model.safetensors:  26% 317M/1.22G [00:19<00:46, 19.3MB/s]
#
#
#
# model.safetensors:  49% 239M/492M [00:19<00:17, 14.6MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 284M/3.44G [00:19<02:52, 18.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  86% 288M/335M [00:19<00:03, 13.7MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 287M/3.44G [00:19<02:40, 19.6MB/s]
#
#
# model.safetensors:  26% 320M/1.22G [00:20<01:00, 14.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  87% 292M/335M [00:19<00:02, 17.5MB/s]
#
#
#
# model.safetensors:  49% 240M/492M [00:20<00:25, 9.90MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  88% 294M/335M [00:19<00:02, 18.5MB/s]
#
#
# model.safetensors:  27% 324M/1.22G [00:20<00:49, 18.2MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 289M/3.44G [00:19<03:41, 14.2MB/s]
#
#
#
# model.safetensors:  50% 244M/492M [00:20<00:18, 13.4MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  89% 297M/335M [00:20<00:01, 19.8MB/s]
#
#
# model.safetensors:  27% 327M/1.22G [00:20<00:45, 19.6MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 292M/3.44G [00:20<03:24, 15.4MB/s]
#
#
#
# model.safetensors:  50% 246M/492M [00:20<00:19, 12.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  90% 301M/335M [00:20<00:01, 20.9MB/s]
#
#
# model.safetensors:  27% 330M/1.22G [00:20<00:44, 20.1MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 295M/3.44G [00:20<03:08, 16.7MB/s]
#
#
#
# model.safetensors:  50% 247M/492M [00:20<00:19, 12.3MB/s]
#
#
# model.safetensors:  27% 333M/1.22G [00:20<00:43, 20.3MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 298M/3.44G [00:20<02:56, 17.7MB/s]
#
#
#
# model.safetensors:  51% 251M/492M [00:20<00:16, 14.7MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 301M/3.44G [00:20<02:43, 19.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  91% 304M/335M [00:20<00:02, 14.3MB/s]
#
#
#
# model.safetensors:  51% 252M/492M [00:20<00:16, 14.6MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 304M/3.44G [00:20<02:37, 20.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  92% 308M/335M [00:20<00:01, 17.4MB/s]
#
#
# model.safetensors:  28% 336M/1.22G [00:20<01:02, 14.2MB/s]
#
#
#
# model.safetensors:  52% 254M/492M [00:20<00:17, 14.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  93% 311M/335M [00:20<00:01, 19.2MB/s]
#
#
# model.safetensors:  28% 340M/1.22G [00:21<00:50, 17.3MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 306M/3.44G [00:20<03:13, 16.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  94% 314M/335M [00:21<00:00, 20.7MB/s]
#
#
# model.safetensors:  28% 343M/1.22G [00:21<00:46, 18.9MB/s]
#
#
#
# model.safetensors:  52% 256M/492M [00:21<00:21, 11.0MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 308M/3.44G [00:21<03:12, 16.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  95% 317M/335M [00:21<00:00, 21.7MB/s]
#
#
# model.safetensors:  28% 346M/1.22G [00:21<00:43, 20.1MB/s]
#
#
#
# model.safetensors:  53% 260M/492M [00:21<00:15, 15.3MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 311M/3.44G [00:21<03:00, 17.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  96% 320M/335M [00:21<00:00, 20.7MB/s]
#
#
# model.safetensors:  29% 349M/1.22G [00:21<00:44, 19.7MB/s]
#
#
#
# model.safetensors:  53% 262M/492M [00:21<00:15, 14.6MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 314M/3.44G [00:21<02:49, 18.4MB/s]
#
#
# model.safetensors:  29% 351M/1.22G [00:21<00:44, 19.2MB/s]
#
#
#
# model.safetensors:  54% 263M/492M [00:21<00:16, 14.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  96% 322M/335M [00:21<00:00, 16.0MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 317M/3.44G [00:21<02:38, 19.7MB/s]
#
#
#
# model.safetensors:  54% 267M/492M [00:21<00:13, 17.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  97% 324M/335M [00:21<00:00, 15.6MB/s]
#
#
# model.safetensors:  29% 353M/1.22G [00:21<00:55, 15.5MB/s]
#
#
#
# model.safetensors:  55% 269M/492M [00:21<00:13, 16.8MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  98% 327M/335M [00:21<00:00, 17.8MB/s]
#
#
# model.safetensors:  29% 356M/1.22G [00:22<00:52, 16.3MB/s]
#
#
#
# model.safetensors:  55% 272M/492M [00:22<00:12, 17.7MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 320M/3.44G [00:21<03:53, 13.4MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  99% 330M/335M [00:21<00:00, 19.2MB/s]
#
#
# model.safetensors:  30% 359M/1.22G [00:22<00:46, 18.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  99% 333M/335M [00:22<00:00, 20.4MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 324M/3.44G [00:21<03:08, 16.5MB/s]
#
#
# model.safetensors:  30% 362M/1.22G [00:22<00:44, 19.0MB/s]
#
#
#
# model.safetensors:  56% 273M/492M [00:22<00:17, 12.8MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 326M/3.44G [00:22<03:07, 16.6MB/s]
#
#
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:22<00:00, 15.0MB/s]
#
#
#
#
# model.safetensors:  56% 276M/492M [00:22<00:15, 14.4MB/s]
#
# diffusion_pytorch_model.safetensors:  10% 329M/3.44G [00:22<02:52, 18.0MB/s]
#
#
#
# model.safetensors:  56% 278M/492M [00:22<00:15, 13.9MB/s]
#
# diffusion_pytorch_model.safetensors:  10% 332M/3.44G [00:22<02:42, 19.1MB/s]
#
#
# model.safetensors:  30% 368M/1.22G [00:22<00:57, 14.7MB/s]
#
#
#
# model.safetensors:  57% 281M/492M [00:22<00:12, 16.4MB/s]
#
# diffusion_pytorch_model.safetensors:  10% 336M/3.44G [00:22<02:31, 20.5MB/s]
#
#
# model.safetensors:  31% 372M/1.22G [00:22<00:46, 18.1MB/s]
#
#
#
# model.safetensors:  58% 284M/492M [00:22<00:12, 17.3MB/s]
#
# diffusion_pytorch_model.safetensors:  10% 338M/3.44G [00:22<03:09, 16.4MB/s]
#
#
# model.safetensors:  31% 375M/1.22G [00:22<00:42, 19.8MB/s]
#
#
#
# model.safetensors:  58% 287M/492M [00:23<00:11, 17.7MB/s]
#
# diffusion_pytorch_model.safetensors:  10% 340M/3.44G [00:22<03:05, 16.7MB/s]
#
#
# model.safetensors:  31% 378M/1.22G [00:23<00:41, 20.1MB/s]
#
# diffusion_pytorch_model.safetensors:  10% 343M/3.44G [00:22<02:46, 18.5MB/s]
#
#
# model.safetensors:  31% 381M/1.22G [00:23<00:40, 20.8MB/s]
#
# diffusion_pytorch_model.safetensors:  10% 346M/3.44G [00:23<02:32, 20.3MB/s]
#
#
#
# model.safetensors:  59% 289M/492M [00:23<00:17, 11.8MB/s]
#
# diffusion_pytorch_model.safetensors:  10% 349M/3.44G [00:23<02:21, 21.9MB/s]
#
#
# model.safetensors:  32% 384M/1.22G [00:23<00:49, 16.8MB/s]
#
#
#
# model.safetensors:  59% 292M/492M [00:23<00:13, 14.9MB/s]
#
#
#
# model.safetensors:  60% 294M/492M [00:23<00:13, 15.1MB/s]
#
#
# model.safetensors:  32% 388M/1.22G [00:23<00:42, 19.5MB/s]
#
#
# model.safetensors:  32% 391M/1.22G [00:23<00:39, 20.8MB/s]
#
#
#
# model.safetensors:  60% 297M/492M [00:23<00:12, 16.3MB/s]
#
# diffusion_pytorch_model.safetensors:  10% 352M/3.44G [00:23<03:37, 14.2MB/s]
#
#
# model.safetensors:  32% 394M/1.22G [00:23<00:37, 21.9MB/s]
#
#
#
# model.safetensors:  61% 300M/492M [00:23<00:11, 17.2MB/s]
#
# diffusion_pytorch_model.safetensors:  10% 356M/3.44G [00:23<02:55, 17.6MB/s]
#
#
# model.safetensors:  33% 397M/1.22G [00:24<00:36, 22.5MB/s]
#
#
#
# model.safetensors:  61% 302M/492M [00:24<00:10, 17.5MB/s]
#
# diffusion_pytorch_model.safetensors:  10% 359M/3.44G [00:23<02:42, 18.9MB/s]
#
# diffusion_pytorch_model.safetensors:  11% 362M/3.44G [00:23<02:33, 20.1MB/s]
#
# diffusion_pytorch_model.safetensors:  11% 365M/3.44G [00:24<02:22, 21.6MB/s]
#
#
# model.safetensors:  33% 400M/1.22G [00:24<00:53, 15.1MB/s]
#
#
#
# model.safetensors:  62% 304M/492M [00:24<00:16, 11.6MB/s]
#
#
# model.safetensors:  33% 404M/1.22G [00:24<00:44, 18.4MB/s]
#
#
#
# model.safetensors:  63% 308M/492M [00:24<00:12, 15.1MB/s]
#
#
# model.safetensors:  33% 407M/1.22G [00:24<00:40, 20.1MB/s]
#
# diffusion_pytorch_model.safetensors:  11% 368M/3.44G [00:24<03:10, 16.1MB/s]
#
#
#
# model.safetensors:  63% 310M/492M [00:24<00:11, 15.3MB/s]
#
#
# model.safetensors:  34% 410M/1.22G [00:24<00:37, 21.6MB/s]
#
# ...
#
# diffusion_pytorch_model.safetensors:  77% 2.65G/3.44G [02:15<00:29, 26.9MB/s]
#
# diffusion_pytorch_model.safetensors:  77% 2.65G/3.44G [02:16<00:28, 27.2MB/s]
#
# diffusion_pytorch_model.safetensors:  77% 2.66G/3.44G [02:16<00:27, 28.3MB/s]
#
# diffusion_pytorch_model.safetensors:  77% 2.66G/3.44G [02:16<00:32, 23.7MB/s]
#
# diffusion_pytorch_model.safetensors:  77% 2.66G/3.44G [02:16<00:30, 25.9MB/s]
#
# diffusion_pytorch_model.safetensors:  78% 2.67G/3.44G [02:16<00:28, 26.7MB/s]
#
# diffusion_pytorch_model.safetensors:  78% 2.67G/3.44G [02:16<00:27, 27.9MB/s]
#
# diffusion_pytorch_model.safetensors:  78% 2.67G/3.44G [02:17<00:32, 23.4MB/s]
#
# diffusion_pytorch_model.safetensors:  78% 2.68G/3.44G [02:17<00:29, 25.8MB/s]
#
# diffusion_pytorch_model.safetensors:  78% 2.68G/3.44G [02:17<00:30, 24.8MB/s]
#
# diffusion_pytorch_model.safetensors:  78% 2.69G/3.44G [02:17<00:25, 29.5MB/s]
#
# diffusion_pytorch_model.safetensors:  78% 2.69G/3.44G [02:17<00:33, 22.6MB/s]
#
# diffusion_pytorch_model.safetensors:  78% 2.69G/3.44G [02:17<00:27, 26.8MB/s]
#
# diffusion_pytorch_model.safetensors:  78% 2.70G/3.44G [02:17<00:27, 27.2MB/s]
#
# diffusion_pytorch_model.safetensors:  79% 2.70G/3.44G [02:18<00:25, 28.3MB/s]
#
# diffusion_pytorch_model.safetensors:  79% 2.71G/3.44G [02:18<00:29, 24.9MB/s]
#
# diffusion_pytorch_model.safetensors:  79% 2.71G/3.44G [02:18<00:27, 26.5MB/s]
#
# diffusion_pytorch_model.safetensors:  79% 2.71G/3.44G [02:18<00:26, 27.0MB/s]
#
# diffusion_pytorch_model.safetensors:  79% 2.72G/3.44G [02:18<00:25, 28.4MB/s]
#
# diffusion_pytorch_model.safetensors:  79% 2.72G/3.44G [02:18<00:28, 25.5MB/s]
#
# diffusion_pytorch_model.safetensors:  79% 2.73G/3.44G [02:18<00:26, 26.8MB/s]
#
# diffusion_pytorch_model.safetensors:  79% 2.73G/3.44G [02:19<00:27, 25.8MB/s]
#
# diffusion_pytorch_model.safetensors:  80% 2.73G/3.44G [02:19<00:23, 29.9MB/s]
#
# diffusion_pytorch_model.safetensors:  80% 2.74G/3.44G [02:19<00:30, 22.7MB/s]
#
# diffusion_pytorch_model.safetensors:  80% 2.74G/3.44G [02:19<00:26, 26.3MB/s]
#
# diffusion_pytorch_model.safetensors:  80% 2.75G/3.44G [02:19<00:25, 26.9MB/s]
#
# diffusion_pytorch_model.safetensors:  80% 2.75G/3.44G [02:19<00:24, 28.3MB/s]
#
# diffusion_pytorch_model.safetensors:  80% 2.75G/3.44G [02:20<00:27, 25.3MB/s]
#
# diffusion_pytorch_model.safetensors:  80% 2.76G/3.44G [02:20<00:25, 26.7MB/s]
#
# diffusion_pytorch_model.safetensors:  80% 2.76G/3.44G [02:20<00:24, 27.2MB/s]
#
# diffusion_pytorch_model.safetensors:  80% 2.77G/3.44G [02:20<00:23, 28.9MB/s]
#
# diffusion_pytorch_model.safetensors:  81% 2.77G/3.44G [02:20<00:27, 24.4MB/s]
#
# diffusion_pytorch_model.safetensors:  81% 2.77G/3.44G [02:20<00:25, 25.6MB/s]
#
# diffusion_pytorch_model.safetensors:  81% 2.78G/3.44G [02:20<00:25, 26.4MB/s]
#
# diffusion_pytorch_model.safetensors:  81% 2.78G/3.44G [02:21<00:23, 27.7MB/s]
#
# diffusion_pytorch_model.safetensors:  81% 2.79G/3.44G [02:21<00:28, 23.1MB/s]
#
# diffusion_pytorch_model.safetensors:  81% 2.79G/3.44G [02:21<00:25, 25.5MB/s]
#
# diffusion_pytorch_model.safetensors:  81% 2.79G/3.44G [02:21<00:26, 24.7MB/s]
#
# diffusion_pytorch_model.safetensors:  81% 2.80G/3.44G [02:21<00:21, 29.7MB/s]
#
# diffusion_pytorch_model.safetensors:  81% 2.80G/3.44G [02:21<00:27, 23.2MB/s]
#
# diffusion_pytorch_model.safetensors:  82% 2.81G/3.44G [02:22<00:23, 27.1MB/s]
#
# diffusion_pytorch_model.safetensors:  82% 2.81G/3.44G [02:22<00:23, 27.3MB/s]
#
# diffusion_pytorch_model.safetensors:  82% 2.82G/3.44G [02:22<00:21, 28.3MB/s]
#
# diffusion_pytorch_model.safetensors:  82% 2.82G/3.44G [02:22<00:26, 23.4MB/s]
#
# diffusion_pytorch_model.safetensors:  82% 2.82G/3.44G [02:22<00:24, 25.7MB/s]
#
# diffusion_pytorch_model.safetensors:  82% 2.83G/3.44G [02:22<00:24, 24.6MB/s]
#
# diffusion_pytorch_model.safetensors:  82% 2.83G/3.44G [02:22<00:20, 29.1MB/s]
#
# diffusion_pytorch_model.safetensors:  82% 2.83G/3.44G [02:23<00:25, 23.5MB/s]
#
# diffusion_pytorch_model.safetensors:  83% 2.84G/3.44G [02:23<00:22, 27.1MB/s]
#
# diffusion_pytorch_model.safetensors:  83% 2.84G/3.44G [02:23<00:21, 27.4MB/s]
#
# diffusion_pytorch_model.safetensors:  83% 2.85G/3.44G [02:23<00:20, 28.8MB/s]
#
# diffusion_pytorch_model.safetensors:  83% 2.85G/3.44G [02:23<00:22, 26.3MB/s]
#
# diffusion_pytorch_model.safetensors:  83% 2.85G/3.44G [02:23<00:23, 24.5MB/s]
#
# diffusion_pytorch_model.safetensors:  83% 2.86G/3.44G [02:24<00:20, 28.6MB/s]
#
# diffusion_pytorch_model.safetensors:  83% 2.86G/3.44G [02:24<00:20, 28.3MB/s]
#
# diffusion_pytorch_model.safetensors:  83% 2.87G/3.44G [02:27<02:32, 3.74MB/s]
#
# diffusion_pytorch_model.safetensors:  83% 2.87G/3.44G [02:27<02:29, 3.82MB/s]
#
# diffusion_pytorch_model.safetensors:  84% 2.87G/3.44G [02:27<01:52, 5.02MB/s]
#
# diffusion_pytorch_model.safetensors:  84% 2.88G/3.44G [02:28<01:14, 7.57MB/s]
#
# diffusion_pytorch_model.safetensors:  84% 2.88G/3.44G [02:28<00:59, 9.46MB/s]
#
# diffusion_pytorch_model.safetensors:  84% 2.88G/3.44G [02:28<00:54, 10.2MB/s]
#
# diffusion_pytorch_model.safetensors:  84% 2.89G/3.44G [02:28<00:42, 13.0MB/s]
#
# diffusion_pytorch_model.safetensors:  84% 2.89G/3.44G [02:28<00:33, 16.2MB/s]
#
# diffusion_pytorch_model.safetensors:  84% 2.90G/3.44G [02:28<00:27, 19.8MB/s]
#
# diffusion_pytorch_model.safetensors:  84% 2.90G/3.44G [02:28<00:28, 19.0MB/s]
#
# diffusion_pytorch_model.safetensors:  84% 2.90G/3.44G [02:29<00:25, 21.5MB/s]
#
# diffusion_pytorch_model.safetensors:  85% 2.91G/3.44G [02:29<00:22, 23.4MB/s]
#
# diffusion_pytorch_model.safetensors:  85% 2.91G/3.44G [02:29<00:20, 25.8MB/s]
#
# diffusion_pytorch_model.safetensors:  85% 2.91G/3.44G [02:29<00:22, 23.2MB/s]
#
# diffusion_pytorch_model.safetensors:  85% 2.92G/3.44G [02:29<00:20, 25.2MB/s]
#
# diffusion_pytorch_model.safetensors:  85% 2.92G/3.44G [02:29<00:19, 26.0MB/s]
#
# diffusion_pytorch_model.safetensors:  85% 2.93G/3.44G [02:30<00:19, 26.6MB/s]
#
# diffusion_pytorch_model.safetensors:  85% 2.93G/3.44G [02:30<00:22, 22.8MB/s]
#
# diffusion_pytorch_model.safetensors:  85% 2.93G/3.44G [02:30<00:21, 23.0MB/s]
#
# diffusion_pytorch_model.safetensors:  86% 2.94G/3.44G [02:30<00:16, 29.6MB/s]
#
# diffusion_pytorch_model.safetensors:  86% 2.94G/3.44G [02:30<00:18, 27.4MB/s]
#
# diffusion_pytorch_model.safetensors:  86% 2.95G/3.44G [02:30<00:20, 24.0MB/s]
#
# diffusion_pytorch_model.safetensors:  86% 2.95G/3.44G [02:30<00:19, 25.3MB/s]
#
# diffusion_pytorch_model.safetensors:  86% 2.95G/3.44G [02:31<00:18, 26.3MB/s]
#
# diffusion_pytorch_model.safetensors:  86% 2.96G/3.44G [02:31<00:17, 27.5MB/s]
#
# diffusion_pytorch_model.safetensors:  86% 2.96G/3.44G [02:31<00:21, 22.0MB/s]
#
# diffusion_pytorch_model.safetensors:  86% 2.97G/3.44G [02:31<00:20, 22.6MB/s]
#
# diffusion_pytorch_model.safetensors:  86% 2.97G/3.44G [02:31<00:17, 27.4MB/s]
#
# diffusion_pytorch_model.safetensors:  87% 2.97G/3.44G [02:31<00:17, 26.9MB/s]
#
# diffusion_pytorch_model.safetensors:  87% 2.98G/3.44G [02:32<00:19, 23.3MB/s]
#
# diffusion_pytorch_model.safetensors:  87% 2.98G/3.44G [02:32<00:17, 26.4MB/s]
#
# diffusion_pytorch_model.safetensors:  87% 2.99G/3.44G [02:32<00:16, 26.9MB/s]
#
# diffusion_pytorch_model.safetensors:  87% 2.99G/3.44G [02:32<00:15, 28.7MB/s]
#
# diffusion_pytorch_model.safetensors:  87% 2.99G/3.44G [02:32<00:17, 25.0MB/s]
#
# diffusion_pytorch_model.safetensors:  87% 3.00G/3.44G [02:32<00:17, 25.1MB/s]
#
# diffusion_pytorch_model.safetensors:  87% 3.00G/3.44G [02:32<00:17, 25.5MB/s]
#
# diffusion_pytorch_model.safetensors:  87% 3.01G/3.44G [02:33<00:14, 29.1MB/s]
#
# diffusion_pytorch_model.safetensors:  88% 3.01G/3.44G [02:33<00:18, 23.0MB/s]
#
# diffusion_pytorch_model.safetensors:  88% 3.01G/3.44G [02:33<00:17, 24.5MB/s]
#
# diffusion_pytorch_model.safetensors:  88% 3.02G/3.44G [02:33<00:14, 29.3MB/s]
#
# diffusion_pytorch_model.safetensors:  88% 3.02G/3.44G [02:33<00:14, 29.6MB/s]
#
# diffusion_pytorch_model.safetensors:  88% 3.03G/3.44G [02:33<00:18, 22.7MB/s]
#
# diffusion_pytorch_model.safetensors:  88% 3.03G/3.44G [02:33<00:15, 26.1MB/s]
#
# diffusion_pytorch_model.safetensors:  88% 3.03G/3.44G [02:34<00:14, 27.0MB/s]
#
# diffusion_pytorch_model.safetensors:  88% 3.04G/3.44G [02:34<00:14, 28.2MB/s]
#
# diffusion_pytorch_model.safetensors:  88% 3.04G/3.44G [02:34<00:16, 24.5MB/s]
#
# diffusion_pytorch_model.safetensors:  89% 3.05G/3.44G [02:34<00:15, 26.1MB/s]
#
# diffusion_pytorch_model.safetensors:  89% 3.05G/3.44G [02:34<00:14, 26.7MB/s]
#
# diffusion_pytorch_model.safetensors:  89% 3.06G/3.44G [02:34<00:13, 28.1MB/s]
#
# diffusion_pytorch_model.safetensors:  89% 3.06G/3.44G [02:35<00:15, 24.9MB/s]
#
# diffusion_pytorch_model.safetensors:  89% 3.06G/3.44G [02:35<00:15, 24.4MB/s]
#
# diffusion_pytorch_model.safetensors:  89% 3.07G/3.44G [02:35<00:12, 29.4MB/s]
#
# diffusion_pytorch_model.safetensors:  89% 3.07G/3.44G [02:35<00:14, 25.4MB/s]
#
# diffusion_pytorch_model.safetensors:  89% 3.07G/3.44G [02:35<00:18, 19.5MB/s]
#
# diffusion_pytorch_model.safetensors:  90% 3.08G/3.44G [02:35<00:17, 21.1MB/s]
#
# diffusion_pytorch_model.safetensors:  90% 3.08G/3.44G [02:36<00:13, 26.6MB/s]
#
# diffusion_pytorch_model.safetensors:  90% 3.09G/3.44G [02:36<00:13, 25.3MB/s]
#
# diffusion_pytorch_model.safetensors:  90% 3.09G/3.44G [02:36<00:14, 24.6MB/s]
#
# diffusion_pytorch_model.safetensors:  90% 3.09G/3.44G [02:36<00:13, 25.7MB/s]
#
# diffusion_pytorch_model.safetensors:  90% 3.10G/3.44G [02:36<00:11, 30.2MB/s]
#
# diffusion_pytorch_model.safetensors:  90% 3.10G/3.44G [02:36<00:11, 28.5MB/s]
#
# diffusion_pytorch_model.safetensors:  90% 3.11G/3.44G [02:36<00:13, 24.3MB/s]
#
# diffusion_pytorch_model.safetensors:  90% 3.11G/3.44G [02:37<00:13, 24.6MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 3.11G/3.44G [02:37<00:10, 29.5MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 3.12G/3.44G [02:37<00:10, 29.4MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 3.12G/3.44G [02:37<00:11, 26.5MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 3.13G/3.44G [02:37<00:12, 24.1MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 3.13G/3.44G [02:37<00:10, 29.0MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 3.13G/3.44G [02:38<00:10, 28.0MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 3.14G/3.44G [02:38<00:12, 24.2MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 3.14G/3.44G [02:38<00:12, 24.3MB/s]
#
# diffusion_pytorch_model.safetensors:  92% 3.15G/3.44G [02:38<00:09, 29.3MB/s]
#
# diffusion_pytorch_model.safetensors:  92% 3.15G/3.44G [02:38<00:09, 29.2MB/s]
#
# diffusion_pytorch_model.safetensors:  92% 3.15G/3.44G [02:38<00:12, 23.6MB/s]
#
# diffusion_pytorch_model.safetensors:  92% 3.16G/3.44G [02:38<00:12, 22.4MB/s]
#
# diffusion_pytorch_model.safetensors:  92% 3.16G/3.44G [02:39<00:09, 27.5MB/s]
#
# diffusion_pytorch_model.safetensors:  92% 3.17G/3.44G [02:39<00:10, 27.1MB/s]
#
# diffusion_pytorch_model.safetensors:  92% 3.17G/3.44G [02:39<00:10, 26.3MB/s]
#
# diffusion_pytorch_model.safetensors:  92% 3.17G/3.44G [02:39<00:10, 25.9MB/s]
#
# diffusion_pytorch_model.safetensors:  92% 3.18G/3.44G [02:39<00:08, 30.9MB/s]
#
# diffusion_pytorch_model.safetensors:  93% 3.18G/3.44G [02:39<00:08, 31.1MB/s]
#
# diffusion_pytorch_model.safetensors:  93% 3.19G/3.44G [02:40<00:26, 9.66MB/s]
#
# diffusion_pytorch_model.safetensors:  93% 3.19G/3.44G [02:41<00:24, 10.4MB/s]
#
# diffusion_pytorch_model.safetensors:  93% 3.19G/3.44G [02:41<00:18, 13.4MB/s]
#
# diffusion_pytorch_model.safetensors:  93% 3.20G/3.44G [02:41<00:16, 14.9MB/s]
#
# diffusion_pytorch_model.safetensors:  93% 3.20G/3.44G [02:41<00:13, 17.9MB/s]
#
# diffusion_pytorch_model.safetensors:  93% 3.20G/3.44G [02:41<00:12, 19.1MB/s]
#
# diffusion_pytorch_model.safetensors:  93% 3.21G/3.44G [02:41<00:10, 22.3MB/s]
#
# diffusion_pytorch_model.safetensors:  93% 3.21G/3.44G [02:41<00:09, 24.4MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 3.22G/3.44G [02:41<00:08, 26.2MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 3.22G/3.44G [02:42<00:09, 23.1MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 3.22G/3.44G [02:42<00:08, 25.4MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 3.23G/3.44G [02:42<00:08, 26.3MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 3.23G/3.44G [02:42<00:07, 27.6MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 3.23G/3.44G [02:42<00:08, 24.2MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 3.24G/3.44G [02:42<00:07, 26.3MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 3.24G/3.44G [02:42<00:07, 27.1MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 3.25G/3.44G [02:43<00:06, 28.2MB/s]
#
# diffusion_pytorch_model.safetensors:  95% 3.25G/3.44G [02:43<00:07, 24.8MB/s]
#
# diffusion_pytorch_model.safetensors:  95% 3.25G/3.44G [02:43<00:06, 26.7MB/s]
#
# diffusion_pytorch_model.safetensors:  95% 3.26G/3.44G [02:43<00:06, 27.3MB/s]
#
# diffusion_pytorch_model.safetensors:  95% 3.26G/3.44G [02:43<00:06, 28.2MB/s]
#
# diffusion_pytorch_model.safetensors:  95% 3.27G/3.44G [02:43<00:07, 23.9MB/s]
#
# diffusion_pytorch_model.safetensors:  95% 3.27G/3.44G [02:43<00:06, 26.5MB/s]
#
# diffusion_pytorch_model.safetensors:  95% 3.27G/3.44G [02:44<00:06, 26.8MB/s]
#
# diffusion_pytorch_model.safetensors:  95% 3.28G/3.44G [02:44<00:05, 28.1MB/s]
#
# diffusion_pytorch_model.safetensors:  95% 3.28G/3.44G [02:44<00:06, 25.3MB/s]
#
# diffusion_pytorch_model.safetensors:  96% 3.29G/3.44G [02:44<00:05, 27.2MB/s]
#
# diffusion_pytorch_model.safetensors:  96% 3.29G/3.44G [02:44<00:05, 27.5MB/s]
#
# diffusion_pytorch_model.safetensors:  96% 3.30G/3.44G [02:44<00:05, 28.5MB/s]
#
# diffusion_pytorch_model.safetensors:  96% 3.30G/3.44G [02:45<00:05, 25.7MB/s]
#
# diffusion_pytorch_model.safetensors:  96% 3.30G/3.44G [02:45<00:04, 27.6MB/s]
#
# diffusion_pytorch_model.safetensors:  96% 3.31G/3.44G [02:45<00:04, 27.8MB/s]
#
# diffusion_pytorch_model.safetensors:  96% 3.31G/3.44G [02:45<00:04, 29.2MB/s]
#
# diffusion_pytorch_model.safetensors:  96% 3.31G/3.44G [02:45<00:04, 25.2MB/s]
#
# diffusion_pytorch_model.safetensors:  96% 3.32G/3.44G [02:45<00:04, 26.3MB/s]
#
# diffusion_pytorch_model.safetensors:  97% 3.32G/3.44G [02:45<00:04, 25.2MB/s]
#
# diffusion_pytorch_model.safetensors:  97% 3.33G/3.44G [02:46<00:03, 30.2MB/s]
#
# diffusion_pytorch_model.safetensors:  97% 3.33G/3.44G [02:46<00:04, 23.5MB/s]
#
# diffusion_pytorch_model.safetensors:  97% 3.33G/3.44G [02:46<00:03, 27.4MB/s]
#
# diffusion_pytorch_model.safetensors:  97% 3.34G/3.44G [02:46<00:03, 27.7MB/s]
#
# diffusion_pytorch_model.safetensors:  97% 3.34G/3.44G [02:46<00:03, 29.3MB/s]
#
# diffusion_pytorch_model.safetensors:  97% 3.35G/3.44G [02:46<00:03, 23.8MB/s]
#
# diffusion_pytorch_model.safetensors:  97% 3.35G/3.44G [02:46<00:03, 27.6MB/s]
#
# diffusion_pytorch_model.safetensors:  98% 3.35G/3.44G [02:47<00:03, 27.8MB/s]
#
# diffusion_pytorch_model.safetensors:  98% 3.36G/3.44G [02:47<00:02, 29.0MB/s]
#
# diffusion_pytorch_model.safetensors:  98% 3.36G/3.44G [02:47<00:03, 24.6MB/s]
#
# diffusion_pytorch_model.safetensors:  98% 3.37G/3.44G [02:47<00:03, 23.4MB/s]
#
# diffusion_pytorch_model.safetensors:  98% 3.37G/3.44G [02:47<00:02, 28.3MB/s]
#
# diffusion_pytorch_model.safetensors:  98% 3.37G/3.44G [02:47<00:02, 27.9MB/s]
#
# diffusion_pytorch_model.safetensors:  98% 3.38G/3.44G [02:48<00:02, 22.3MB/s]
#
# diffusion_pytorch_model.safetensors:  98% 3.38G/3.44G [02:48<00:02, 24.0MB/s]
#
# diffusion_pytorch_model.safetensors:  99% 3.39G/3.44G [02:48<00:01, 28.4MB/s]
#
# diffusion_pytorch_model.safetensors:  99% 3.39G/3.44G [02:48<00:01, 28.3MB/s]
#
# diffusion_pytorch_model.safetensors:  99% 3.39G/3.44G [02:48<00:01, 23.6MB/s]
#
# diffusion_pytorch_model.safetensors:  99% 3.40G/3.44G [02:48<00:01, 23.3MB/s]
#
# diffusion_pytorch_model.safetensors:  99% 3.40G/3.44G [02:48<00:01, 27.9MB/s]
#
# diffusion_pytorch_model.safetensors:  99% 3.41G/3.44G [02:49<00:01, 27.9MB/s]
#
# diffusion_pytorch_model.safetensors:  99% 3.41G/3.44G [02:49<00:01, 27.3MB/s]
#
# diffusion_pytorch_model.safetensors:  99% 3.41G/3.44G [02:49<00:00, 26.4MB/s]
#
# diffusion_pytorch_model.safetensors:  99% 3.42G/3.44G [02:49<00:00, 31.2MB/s]
#
# diffusion_pytorch_model.safetensors: 100% 3.42G/3.44G [02:49<00:00, 29.3MB/s]
#
# diffusion_pytorch_model.safetensors: 100% 3.43G/3.44G [02:49<00:00, 24.7MB/s]
#
# diffusion_pytorch_model.safetensors: 100% 3.43G/3.44G [02:49<00:00, 27.1MB/s]
#
# diffusion_pytorch_model.safetensors: 100% 3.44G/3.44G [02:50<00:00, 20.2MB/s]
#
# Upload 10 LFS files: 100% 10/10 [02:52<00:00, 17.25s/it]
# Steps: 100% 400/400 [13:38<00:00,  2.05s/it, loss=0.305, lr=5e-6]

# %%
from diffusers import DiffusionPipeline, UNet2DConditionModel
from transformers import CLIPTextModel
import torch

# Load the pipeline with the same arguments (model, revision) that were used for training
model_id = "CompVis/stable-diffusion-v1-4"

unet = UNet2DConditionModel.from_pretrained("/saved_model/unet")

# if you have trained with `--args.train_text_encoder` make sure to also load the text encoder
text_encoder = CLIPTextModel.from_pretrained("/saved_model/text_encoder")

pipeline = DiffusionPipeline.from_pretrained(
    model_id, unet=unet, text_encoder=text_encoder, dtype=torch.float16, use_safetensors=True
)
pipeline.to("cuda")

# Perform inference, or save, or push to the hub
pipeline.save_pretrained("dreambooth-pipeline")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-40-66f6e0dcefe8> in <cell line: 1>()
# ----> 1 from diffusers import DiffusionPipeline, UNet2DConditionModel
#       2 from transformers import CLIPTextModel
#       3 import torch
#       4
#       5 # Load the pipeline with the same arguments (model, revision) that were used for training
#
# ModuleNotFoundError: No module named 'diffusers'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
